# %% [markdown]
# <a href="https://colab.research.google.com/github/danielafgouvea/cienciadados/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dados = np.random.rand(100)

# %%
plt.plot(dados)
plt.title("Gráfico de Números Aleatórios")
plt.xlabel("Índice")
plt.ylabel("Valor Aleatório")
plt.grid(True)

# %%
plt.savefig("grafico_aleatorio.png")

# %%
from google.colab import files
files.download("grafico_aleatorio.png")

# %%
plt.show()
